# %% [markdown]
# <a href="https://colab.research.google.com/github/Ngtpd/ISYS5002-2023-S1/blob/main/05_2_using_paycalc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import paycalc module

# %%
#1. Dowload the file 05_2_paycalc.py to "Download.py"
#2. Change name to be easy to use 
#3. Upload the file "....py" to this notebook

# %%
import paycal as pay
#Can only enter import paycal not adding "as pay"

# %%
help (pay)      # this function to help how to work this task
# Out:
# Help on module paycal:
#
# NAME
#     paycal - 05_2_paycalc.ipynb
#
# DESCRIPTION
#     Automatically generated by Colaboratory.
#
#     Original file is located at
#         https://colab.research.google.com/drive/1XiCLJEDBWZPTSVSm7J6oELfhqxocXJoj
#
# FUNCTIONS
#     calculate_pay(salary, sales, comm)
#         This function calculates the commission, tax, and pay for a given salary, sales, and commission rate.
#
#         Inputs:
#         salary: an integer representing the user's salary
#         sales: an integer representing the user's sales
#         comm: a float representing the user's commission rate
#
#         Returns:
#         commission: a float representing the commission earned based on the sales and commission rate
#         tax: a float representing the tax amount calculated based on the salary and commission earned
#         pay: a float representing the pay after deducting tax from the salary and adding the commission earned
#
#     calculate_tax(income)
#
# ...

# %% [markdown]
# ## call the relevant functions from the `paycalc` module to
# * get user input
# * calculate the pay
# * print the payslip

# %%
#templete: module name . function name with input parameters

pay.user_input()
# Out:
# Please enter name: D
# Please enter salary: 3000
# Please enter sales: 2000
# Please enter commission rate: 2
# ('D', 3000, 2000, 2.0)

# %%
#insert the caption name (that use for pay.calculate_pay() )
name, salary, sales, comm_rate = pay.user_input()
# Out:
# Please enter name: d
# Please enter salary: 2000
# Please enter sales: 3000
# Please enter commission rate: 1

# %%
comm_result, tax_result, pay_result = pay.calculate_pay(salary, sales, comm_rate )

# %%
pay.print_payslip(name, salary, comm_result, tax_result, pay_result)
# Out:
# === Payslip of d ===
# Salary:      2000
# Commission: 30.0
# Tax:             0
# Total pay:   2030.0

# %%
# The Scenario the wrong calculation result 
# recheck why its wrong by "comm_rate" in print_payslip function 
# It must be changed to "comm_result"
name, salary, sales, comm_rate = pay.user_input()
comm_result, tax_result, pay_result = pay.calculate_pay(salary, sales, comm_rate )
pay.print_payslip(name, salary, comm_rate, tax_result, pay_result)
# Out:
# Please enter name: D
# Please enter salary: 2000
# Please enter sales: 3000
# Please enter commission rate: 1
#
# === Payslip of D ===
# Salary:      2000
# Commission: 1.0
# Tax:             0
# Total pay:   2030.0
